# %%
import pandas as pd

# %%
table_url = 'https://www.mapsofworld.com/thematic-maps/types-of-governments.html'
tables = pd.read_html(table_url)
tables
# Out:
# [            0
#  0  Disclaimer,
#                                                     0  \
#  0  CloseDisclaimer : All efforts have been made t...
#
#                                                     1
#  0  CloseDisclaimer : All efforts have been made t...  ,
#                                                     0  \
#  0  ColorGovernment Type Transitional government F...
#
#                                                     1
#  0  ColorGovernment Type Communist state Democrati...  ,
#      Color                                    Government Type
#  0     NaN                            Transitional government
#  1     NaN                                         Federation
#  2     NaN                        Federal democratic Republic
#  3     NaN     Constitutional monarchy and commonwealth realm
#  4     NaN  Federal Parliamentary democracy and a Commonwe...
#  5     NaN                 Democratic Constitutional Republic
#  6     NaN                             Constitutional emirate
#  7     NaN               Emerging federal democratic Republic
#  8     NaN           Operates under a transitional government
#  9     NaN                                     Military junta
#  10    NaN                            Constitutional Republic
#  11    NaN  A parliamentary democracy, a federation, and a...
#  12    NaN                                   Federal Republic
#  13    NaN                           Constitutional democracy
#  14    NaN                                Theocratic Republic
#  15    NaN  Multiparty democracy under a constitutional mo...
#  16    NaN  Constitution-based Federal Republic; strong de...
#  17    NaN  A parliamentary government with a constitution...,
#      Color                                    Government Type
#  0     NaN                                    Communist state
#  1     NaN                                Democratic Republic
#  2     NaN                                 Federal government
#  3     NaN                                           Monarchy
#  4     NaN  Federal Parliamentary democracy under a consti...
#  5     NaN                                   Islamic Republic
#  6     NaN                                            Emirate
#  7     NaN                   Federated Parliamentary Republic
#  8     NaN      Secular democracy and a presidential Republic
#  9     NaN                 Constitutional democratic Republic
#  10    NaN  formally a confederation but similar in struct...
#  11    NaN                                           Republic
#  12    NaN                                      Parliamentary
#  13    NaN              Parliamentary constitutional monarchy
#  14    NaN                   Sahrawi Arab Democratic Republic
#  15    NaN  Constitutional sultanate (locally known as Mal...
#  16    NaN                               Multiparty democracy
#  17    NaN  Constitutional Parliamentary democracy and a C...,
#           Country                                    Govt Type  \
#  0    Afghanistan                Presidential Islamic republic
#  1        Albania                       Parliamentary republic
#  2        Algeria                        Presidential republic
#  3        Andorra  Unitary parliamentary Semi-Elective diarchy
#  4         Angola                        Presidential republic
#  ..           ...                                          ...
#  188    Venezuela                Federal presidential republic
#  189      Vietnam                              Communist state
#  190        Yemen       in transition (Provisional government)
#  191       Zambia                        Presidential republic
#  192     Zimbabwe                   Semi-presidential republic
#
#                                           Head of State  \
#  0                             President - Ashraf Ghani
#  1                            President - Bujar Nishani
#  2                     President - Abdelaziz Bouteflika
#  3    Episcopal Co-Prince - Joan Enric Vives Sicília...
#  4                  President - Jose Eduardo dos Santos
#  ..                                                 ...
#  188                         President - Nicolas Maduro
#  189                         President - Tran Dại Quang
#  190                  President - Abdrabbuh Mansur Hadi
#  191                            President - Edgar Lungu
#  192                     President - Emmerson Mnangagwa
#
#                                Head of Government
#  0    Chief Executive Officer - Abdullah Abdullah
#  1                      Prime Minister - Edi Rama
#  2             Prime Minister - Abdelmalek Sellal
#  3              Head of Government - Antoni Martí
#  4                                            NaN
#  ..                                           ...
#  188                                          NaN
#  189            Prime Minister - Nguyen Xuan Phúc
#  190       Prime Minister - Ahmed Obeid bin Daghr
#  191                                          NaN
#  192                                          NaN
#
#  [193 rows x 4 columns]]

# %%
gov_df = tables[5]
gov_df.columns = ['Country', 'Govt Type', 'Head of State', 'Head of Government']
new_gov_df = gov_df.rename(columns={'Country':'country','Govt Type':'govt_type', 'Head of State':'head_of_state', 'Head of Government':'head_of_government'})
new_gov_df.set_index('country', inplace=True)
new_gov_df
# Out:
#                                                govt_type  \
# country
# Afghanistan                Presidential Islamic republic
# Albania                           Parliamentary republic
# Algeria                            Presidential republic
# Andorra      Unitary parliamentary Semi-Elective diarchy
# Angola                             Presidential republic
# ...                                                  ...
# Venezuela                  Federal presidential republic
# Vietnam                                  Communist state
# Yemen             in transition (Provisional government)
# Zambia                             Presidential republic
# Zimbabwe                      Semi-presidential republic
#
#                                                  head_of_state  \
# country
# Afghanistan                           President - Ashraf Ghani
# Albania                              President - Bujar Nishani
# Algeria                       President - Abdelaziz Bouteflika
# Andorra      Episcopal Co-Prince - Joan Enric Vives Sicília...
# Angola                     President - Jose Eduardo dos Santos
# ...                                                        ...
# Venezuela                           President - Nicolas Maduro
# Vietnam                             President - Tran Dại Quang
# Yemen                        President - Abdrabbuh Mansur Hadi
# Zambia                                 President - Edgar Lungu
# Zimbabwe                        President - Emmerson Mnangagwa
#
#                                       head_of_government
# country
# Afghanistan  Chief Executive Officer - Abdullah Abdullah
# Albania                        Prime Minister - Edi Rama
# Algeria               Prime Minister - Abdelmalek Sellal
# Andorra                Head of Government - Antoni Martí
# Angola                                               NaN
# ...                                                  ...
# Venezuela                                            NaN
# Vietnam                Prime Minister - Nguyen Xuan Phúc
# Yemen             Prime Minister - Ahmed Obeid bin Daghr
# Zambia                                               NaN
# Zimbabwe                                             NaN
#
# [193 rows x 3 columns]

# %%
# The path to our CSV file
file = "../Resources/countries.csv"

hpi_country_df = pd.read_csv(file, encoding='UTF-8')
new_hpi_country_df = hpi_country_df.rename(columns={'Country or region':'country'})

hpi_final = new_hpi_country_df['country']
hpi_final.head(155)
# Out:
# 0      Afghanistan
# 1          Albania
# 2          Algeria
# 3           Angola
# 4        Argentina
#           ...
# 149      Venezuela
# 150        Vietnam
# 151          Yemen
# 152         Zambia
# 153       Zimbabwe
# Name: country, Length: 154, dtype: object

# %%
merge_df = pd.merge(new_gov_df, hpi_final, on=('country'), how='inner')

#clean_df = merge_df.rename(columns={ 'sub_region':'region'})

merge_df
# Out:
#          country                               govt_type  \
# 0    Afghanistan           Presidential Islamic republic
# 1        Albania                  Parliamentary republic
# 2        Algeria                   Presidential republic
# 3         Angola                   Presidential republic
# 4      Argentina                   Presidential republic
# ..           ...                                     ...
# 143    Venezuela           Federal presidential republic
# 144      Vietnam                         Communist state
# 145        Yemen  in transition (Provisional government)
# 146       Zambia                   Presidential republic
# 147     Zimbabwe              Semi-presidential republic
#
#                            head_of_state  \
# 0               President - Ashraf Ghani
# 1              President - Bujar Nishani
# 2       President - Abdelaziz Bouteflika
# 3    President - Jose Eduardo dos Santos
# 4             President - Mauricio Macri
# ..                                   ...
# 143           President - Nicolas Maduro
# 144           President - Tran Dại Quang
# 145    President - Abdrabbuh Mansur Hadi
# 146              President - Edgar Lungu
# 147       President - Emmerson Mnangagwa
#
#                               head_of_government
# 0    Chief Executive Officer - Abdullah Abdullah
# 1                      Prime Minister - Edi Rama
# 2             Prime Minister - Abdelmalek Sellal
# 3                                            NaN
# 4                                            NaN
# ..                                           ...
# 143                                          NaN
# 144            Prime Minister - Nguyen Xuan Phúc
# 145       Prime Minister - Ahmed Obeid bin Daghr
# 146                                          NaN
# 147                                          NaN
#
# [148 rows x 4 columns]

# %%
from sqlalchemy import create_engine
from config import postgres_pwd, postgres_user

db_name = "happiness_db"
table_name = "countries_by_government"

connection_string = f"{postgres_user}:{postgres_pwd}@localhost:5432/{db_name}"
engine = create_engine(f'postgresql://{connection_string}')
conn = engine.connect()

merge_df.to_sql(table_name, con=engine, if_exists="append", index=False)

conn.close()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-6-0d51b339c4d1> in <module>
#       1 from sqlalchemy import create_engine
# ----> 2 from config import postgres_pwd
#       3
#       4 db_name = "happiness_db"
#       5 table_name = "countries_by_government"
#
# ImportError: cannot import name 'postgres_pwd' from 'config' (/Users/timsamson/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/config/__init__.py)
